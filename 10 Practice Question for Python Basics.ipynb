# %% [markdown]
# # 🐍 Python Practice Questions
# ## Variables, Data Types, Input/Output, and Operators
#
#
# ---
#
# # 📘 Beginner Level
#
# ## 1. Square of a Number
#
# ### Question
# Take a number as input and print its square.
#
# ---

# %% [markdown]
# ## 2. Area of Rectangle
#
# ### Question
# Write a program to calculate the area of a rectangle.
#
# ---

# %% [markdown]
# ## 3. Celsius to Fahrenheit Converter
#
# ### Question
# Take temperature in Celsius and convert it into Fahrenheit.
#
# ---

# %% [markdown]
# ---
#
# ## 4. Swap Two Variables Using Third Variable
#
# ### Question
# Write a program to swap two variables using a third variable.
#
#
# ---

# %% [markdown]
# ## 5. Even or Odd Number
#
# ### Question
# Check whether a number is even or odd.

# %% [markdown]
# ---
#
# ## 6. Marks, Total and Average
#
# ### Question
# Take marks of 5 subjects and calculate total and average.
#
# ---

# %% [markdown]
# ## 7. Simple Interest
#
# ### Question
# Write a program to calculate simple interest.
#
# ---

# %% [markdown]
# ## 8. Circumference of Circle
#
# ### Question
# Calculate the circumference of a circle.
#
# ---

# %% [markdown]
# ## 9. Greater and Smaller Number
#
# ### Question
# Take two numbers and print greater and smaller number.
#
# ---

# %% [markdown]
# ## 10. Age Calculator
#
# ### Question
# Take birth year as input and calculate age.
#
# ---
